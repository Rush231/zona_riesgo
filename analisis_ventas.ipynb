# %% [markdown]
# <a href="https://colab.research.google.com/github/Rush231/zona_riesgo/blob/main/analisis_ventas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

import pandas as pd

import plotly.graph_objects as go

# %%
ruta_de_archivos = '/content/drive/MyDrive/tp big data'

traducciones = {
    'Order ID': 'ID de Pedido',
    'Product': 'Producto',
    'Quantity Ordered': 'Cantidad Pedida',
    'Price Each': 'Precio Unitario',
    'Order Date': 'Fecha de Pedido',
    'Purchase Address': 'Dirección de Envio'

}



# Cargar el DataFrame original desde el archivo CSV
ruta_de_archivos =  '/content/drive/MyDrive/tp big data'
archivos = os.listdir(ruta_de_archivos)

dataframes= {}

for archivo in archivos:
    if archivo.endswith('.csv'):  # Asegurarse de que solo se consideren archivos CSV
        mes = archivo.split('_')[3].split('.')[0]  # Obtener el nombre del archivo sin la extensión
        ruta_completa = os.path.join(ruta_de_archivos, archivo)  # Ruta completa al archivo
        df = pd.read_csv(ruta_completa)
        # Cambiar los nombres de las columnas según las traducciones
        df_traducido = df.rename(columns=traducciones)

        # Guardar el DataFrame traducido en un nuevo archivo CSV
        ruta_archivo_traducido =  f'/content/drive/MyDrive/tp big data{mes}.csv'
        df_traducido.to_csv(ruta_archivo_traducido, index=False,mode='w')  # index=False para no guardar el índice en el CSV


df_traducido
# Out:
#       ID de Pedido                Producto Cantidad Pedida Precio Unitario  \
# 0           248151   AA Batteries (4-pack)               4            3.84
# 1           248152    USB-C Charging Cable               2           11.95
# 2           248153    USB-C Charging Cable               1           11.95
# 3           248154        27in FHD Monitor               1          149.99
# 4           248155    USB-C Charging Cable               1           11.95
# ...            ...                     ...             ...             ...
# 11681       259353  AAA Batteries (4-pack)               3            2.99
# 11682       259354                  iPhone               1             700
# 11683       259355                  iPhone               1             700
# 11684       259356  34in Ultrawide Monitor               1          379.99
# 11685       259357    USB-C Charging Cable               1           11.95
#
#       Fecha de Pedido                       Dirección de Envio
# ...

# %%
ruta_de_archivos = '/content/drive/MyDrive/tp big data'
archivos = os.listdir(ruta_de_archivos)

dataframes= {}

for archivo in archivos:
    if archivo.endswith('.csv'):  # Asegurarse de que solo se consideren archivos CSV
        mes = archivo.split('_')[3].split('.')[0]  # Obtener el nombre del archivo sin la extensión
        ruta_completa = os.path.join(ruta_de_archivos, archivo)  # Ruta completa al archivo
        df = pd.read_csv(ruta_completa)  # Cargar el archivo CSV en un DataFrame
        df_ventas = df.copy()

        df_ventas['Cantidad Pedida'] = pd.to_numeric(df_ventas['Cantidad Pedida'], errors='coerce')  #El errors= 'coerce' transforma los valores no numericos a NaN'
        df_ventas['Precio Unitario'] = pd.to_numeric(df_ventas['Precio Unitario'], errors='coerce')


        df_ventas = df_ventas.loc[~df_ventas['Cantidad Pedida'].isna()]
        df_ventas = df_ventas.loc[~df_ventas['Precio Unitario'].isna()]

        # Elimino todos los Nan y me quedo solo con los valores numericos
        df_ventas = df_ventas.dropna()

        # Transformo todos los valores numericos al tipo de dato int
        df_ventas['Cantidad Pedida'] = df_ventas['Cantidad Pedida'].astype(int)
        df_ventas['Precio Unitario'] = df_ventas['Precio Unitario'].astype(int)

        dataframes[mes] = df_ventas  # Agregar el DataFrame al diccionario usando el nombre del mes
#Trasformo los valores en un formato de fecha y hora
df_ventas['Fecha de Compra'] = pd.to_datetime(df_ventas['Fecha de Pedido']) #Si no aplicamos esto, cuando queremos extraer la hora nos tira error
df_ventas
# Out:
#       ID de Pedido                Producto  Cantidad Pedida  Precio Unitario  \
# 0           248151   AA Batteries (4-pack)                4                3
# 1           248152    USB-C Charging Cable                2               11
# 2           248153    USB-C Charging Cable                1               11
# 3           248154        27in FHD Monitor                1              149
# 4           248155    USB-C Charging Cable                1               11
# ...            ...                     ...              ...              ...
# 11681       259353  AAA Batteries (4-pack)                3                2
# 11682       259354                  iPhone                1              700
# 11683       259355                  iPhone                1              700
# 11684       259356  34in Ultrawide Monitor                1              379
# 11685       259357    USB-C Charging Cable                1               11
#
# ...

# %%
#Agrupar produtos con cantidad de productos pedida
Productos_vendidos = df_ventas.groupby('Producto')['Cantidad Pedida'].sum()

# Ordenar de mayor a menor
Productos_vendidos_ordenados = Productos_vendidos.sort_values(ascending = False)

# Crear un nuevo DataFrame con los valores
df_Productos = pd.DataFrame({'Producto':Productos_vendidos_ordenados.index, 'Cantidad Pedida': Productos_vendidos_ordenados.values})

df_Productos
# Out:
#                       Producto  Cantidad Pedida
# 0       AAA Batteries (4-pack)             1927
# 1        AA Batteries (4-pack)             1773
# 2         USB-C Charging Cable             1594
# 3     Lightning Charging Cable             1433
# 4             Wired Headphones             1302
# 5     Apple Airpods Headphones              968
# 6   Bose SoundSport Headphones              830
# 7             27in FHD Monitor              482
# 8                       iPhone              398
# 9       27in 4K Gaming Monitor              382
# 10      34in Ultrawide Monitor              378
# 11                Google Phone              342
# 12               Flatscreen TV              294
# 13          Macbook Pro Laptop              288
# 14                20in Monitor              277
# 15             ThinkPad Laptop              249
# 16             Vareebadd Phone              126
# 17          LG Washing Machine               46
# 18                    LG Dryer               30

# %%
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio',
        'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']

for mes in meses:
  dataframe_mes = dataframes[mes]

# %%
def extraer_datos(datos):
  datos['Fecha de Pedido'] = pd.to_datetime(datos['Fecha de Pedido'])
  datos['Hora'] = datos['Fecha de Pedido'].dt.hour
  datos['Dia'] = datos['Fecha de Pedido'].dt.day
  return datos

dataframe_mes = extraer_datos(dataframe_mes)

# %%
import pandas as pd
import plotly.graph_objects as go


# Creo listas para almacenar los totales de ventas y los nombres de los meses
totales_ventas = []
nombres_meses = []

for mes in meses:
    dataframe_mes = dataframes[mes]
    dataframe_mes = extraer_datos(dataframe_mes)

    total_ventas_mes = dataframe_mes['Cantidad Pedida'].sum()
    totales_ventas.append(total_ventas_mes)
    nombres_meses.append(mes)

# Creo el objeto figura con el gráfico de barras
fig = go.Figure()

fig.add_trace(go.Bar(
    x=nombres_meses,
    y=totales_ventas,
    marker=dict(color=totales_ventas, colorscale = 'RdYlGn', colorbar=dict(title="Total de ventas", x=1.0, thickness=15)),  # Color y barra de colores
    text=totales_ventas,
    textposition='auto',  # Muestro el valor encima de las barras

))

# Configuro los ejes y los títulos
fig.update_layout(
    title="Total de ventas por mes",
    xaxis=dict(title="Mes"),
    yaxis=dict(title="Total de ventas"),
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# El total de ingresos por cada mes fue de:
#
#        enero            10868
#      febrero            13461
#        marzo            17005
#        abril            20558
#         mayo            18657
#        junio            15255
#        julio            16069
#       agosto            13442
#   septiembre            13119
#      octubre            22705
#    noviembre            19808
#    diciembre            28121

# %%
meses
# Out:
# ['Enero',
#  'Febrero',
#  'Marzo',
#  'Abril',
#  'Mayo',
#  'Junio',
#  'Julio',
#  'Agosto',
#  'Septiembre',
#  'Octubre',
#  'Noviembre',
#  'Diciembre']

# %%
import pandas as pd
import plotly.graph_objects as go

Horas = list(range(24))

# Creo el objeto figura
fig = go.Figure()
horas_analizadas = [19, 12, 16]

for hora in horas_analizadas:
    total_productos_vendidos = []

    for mes in meses:
        dataframe_mes = dataframes[mes]
        dataframe_mes = extraer_datos(dataframe_mes)

        ventas_hora = dataframe_mes[dataframe_mes['Hora'] == hora]

        # Calcular la cantidad total de productos vendidos para la hora actual
        total_productos_vendidos.append(ventas_hora['Cantidad Pedida'].count())

    # Agrego al objeto figura un gráfico de línea con las horas y las ventas por hora
    fig.add_trace(go.Scatter(
        x=meses,
        y=total_productos_vendidos,
        mode='lines',
        name=f'{hora} horas',
        line=dict(width=2, shape='spline'),
    ))

# Configuro los ejes y los títulos
fig.update_layout(
    title="Unidades vendidas por hora",
    xaxis=dict(title="Meses", tickvals=Horas),
    yaxis=dict(title="Unidades vendidas", side="left"),
    legend=dict(y=0.3, yanchor='bottom'),
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.graph_objects as go

Horas = list(range(24))

# Creo el objeto figura
fig = go.Figure()

for mes in meses:
    dataframe_mes = dataframes[mes]
    dataframe_mes = extraer_datos(dataframe_mes)  # Reemplaza esto con el procesamiento que necesites
    Ventas_por_hora = dataframe_mes.groupby('Hora')['Cantidad Pedida'].count()



    # Agrego al objeto figura un gráfico de línea con las horas y las ventas por hora
    fig.add_trace(go.Scatter(
        x=Horas,
        y=Ventas_por_hora,
        mode='lines',
        name=mes,
        line=dict(width=2,shape='spline'),
    ))

# Configuro los ejes y los títulos
fig.update_layout(
    title="Unidades vendidas por hora en diferentes meses",
    xaxis=dict(title="Hora", tickvals=Horas),
    yaxis=dict(title="Unidades vendidas", side="left"),
    legend=dict(y=0.3, yanchor='bottom'),
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ventas_por_dia =dataframe_mes.groupby('Dia')['Cantidad Pedida'].sum()
dias= list(ventas_por_dia.index)

# Crear el objeto figura
fig = go.Figure()

# Agrego al objeto figura un grafico de de linea con las horas y las ventas por hora
fig.add_trace(go.Scatter(
        x = dias,
        y= ventas_por_dia,
        name = 'Ventas por dia',
        line = dict(color= 'Red',shape='spline',smoothing=1.3,width=3),

        )
)

# Configuro los ejes y los títulos
fig.update_layout(
    title = 'Unidades Vendidas por dia',
    xaxis = dict(title='Dias', tickvals=dias),  # Para que en el eje x se muestren todos los valores uso tickvals=Horas
    yaxis = dict(title='Unidades Vendidas',side='left'),


)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Extraigo valores del dataFrame para realizar el grafico
Analisis_de_productos = df_ventas.groupby('Producto').agg({
    'Cantidad Pedida':'sum',
    'Precio Unitario': 'mean'
})

# Ordeno de mayor a menor
Analisis_de_productos = Analisis_de_productos.sort_values(by='Cantidad Pedida', ascending = False)

# Reseteo Indice
Analisis_de_productos = Analisis_de_productos.reset_index(inplace=False)

Analisis_de_productos
# Out:
#                       Producto  Cantidad Pedida  Precio Unitario
# 0       AAA Batteries (4-pack)             1927              2.0
# 1        AA Batteries (4-pack)             1773              3.0
# 2         USB-C Charging Cable             1594             11.0
# 3     Lightning Charging Cable             1433             14.0
# 4             Wired Headphones             1302             11.0
# 5     Apple Airpods Headphones              968            150.0
# 6   Bose SoundSport Headphones              830             99.0
# 7             27in FHD Monitor              482            149.0
# 8                       iPhone              398            700.0
# 9       27in 4K Gaming Monitor              382            389.0
# 10      34in Ultrawide Monitor              378            379.0
# 11                Google Phone              342            600.0
# 12               Flatscreen TV              294            300.0
# ...

# %%
import plotly.graph_objects as go

# Extraigo valores del dataFrame para realizar los graficos
Productos = df_Productos['Producto']
Unidades = df_Productos['Cantidad Pedida']

#Creo el objeto figura
fig = go.Figure()

#Agrego grafico en mi objeto figura
fig.add_trace(go.Bar(
        x = Productos,
        y= Unidades,
        name = 'Unidades Vendidas',
        marker = dict(color= 'Light Blue')
)
)

# Configuro titulos y ejes del grafico
fig.update_layout(
    title = 'Unidades Vendidas',
    xaxis = dict(title='Productos'),
    yaxis = dict(title='Unidades')

)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

# Extraigo valores
Productos = Analisis_de_productos['Producto']
Unidades = Analisis_de_productos['Cantidad Pedida']
Precio = Analisis_de_productos['Precio Unitario']


# Crear el objeto figura
fig = go.Figure()

fig.add_trace(go.Bar(
        x = Productos,
        y= Unidades,
        name = 'Unidades Vendidas',
        marker = dict(color= 'Light Blue'),
        yaxis= 'y'
)
)

# Agrego al objeto figura un grafico de de linea conn los valores extraidos previamente de Productoos y precios
fig.add_trace(go.Scatter(
        x = Productos,
        y= Precio,
        name = 'Precio unitario',
        line = dict(color= 'Red',shape='spline',smoothing=1.3,width=3),   # Realizo ajustes para la línea suave y ancha
        yaxis = 'y2'
        )
)

# Configuro los ejes y los títulos
fig.update_layout(
    title = 'Unidades Vendidas y Precios de productos',
    xaxis = dict(title='Productos'),
    yaxis = dict(title='Unidades',side='left'),
    yaxis2 = dict(title='Precio', overlaying= 'y',side='right'),
    yaxis_range = [0, max(Unidades)*1.1],
    yaxis2_range = [0, max(Precio)*1.1]
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Separo la direccion de envio en calle ciudad y PO BOX
direccion_df = df_ventas['Dirección de Envio'].str.split(', ',expand=True)
direccion_df.columns = ['Calle','Ciudad','PO BOX']

# Separo el PO BOX en Estado y Cod Postal
direccion_df[['Estado', 'Cod Postal']] = direccion_df['PO BOX'].str.split(' ',expand=True)
df_ventas_desglosado = pd.concat([df_ventas,direccion_df],axis=True)
df_ventas_desglosado
# Out:
#       ID de Pedido                Producto  Cantidad Pedida  Precio Unitario  \
# 0           248151   AA Batteries (4-pack)                4                3
# 1           248152    USB-C Charging Cable                2               11
# 2           248153    USB-C Charging Cable                1               11
# 3           248154        27in FHD Monitor                1              149
# 4           248155    USB-C Charging Cable                1               11
# ...            ...                     ...              ...              ...
# 11681       259353  AAA Batteries (4-pack)                3                2
# 11682       259354                  iPhone                1              700
# 11683       259355                  iPhone                1              700
# 11684       259356  34in Ultrawide Monitor                1              379
# 11685       259357    USB-C Charging Cable                1               11
#
# ...

# %%
df_ventas_desglosado['Fecha de Pedido'] = pd.to_datetime(df_ventas_desglosado['Fecha de Pedido'])

df_ventas_desglosado['Mes'] = df_ventas_desglosado['Fecha de Pedido'].dt.to_period('M')
print(df_ventas_desglosado)
# Out:
#       ID de Pedido                Producto  Cantidad Pedida  Precio Unitario  \
# 0           248151   AA Batteries (4-pack)                4                3
# 1           248152    USB-C Charging Cable                2               11
# 2           248153    USB-C Charging Cable                1               11
# 3           248154        27in FHD Monitor                1              149
# 4           248155    USB-C Charging Cable                1               11
# ...            ...                     ...              ...              ...
# 11681       259353  AAA Batteries (4-pack)                3                2
# 11682       259354                  iPhone                1              700
# 11683       259355                  iPhone                1              700
# 11684       259356  34in Ultrawide Monitor                1              379
# 11685       259357    USB-C Charging Cable                1               11
#
# ...

# %%
# Agrupo por estado y cantidad de productos vendidos
ventas_por_estado = df_ventas_desglosado.groupby('Estado')['Cantidad Pedida'].sum()

# Reseteo el indice
ventas_por_estado = ventas_por_estado.reset_index(inplace=False)
ventas_por_estado
# Out:
#   Estado  Cantidad Pedida
# 0     CA             5211
# 1     GA             1035
# 2     MA             1455
# 3     ME              161
# 4     NY             1711
# 5     OR              668
# 6     TX             1820
# 7     WA             1058

# %%
import plotly.express as px


# Hago un plot de Estados Unidos
fig = px.choropleth(ventas_por_estado, locations='Estado', locationmode='USA-states',color='Cantidad Pedida',
                           color_continuous_scale="RdYlGn",
                           scope="usa",
                          title= 'Ventas por estado'
                          )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Agrupar los datos por día y calcular las ventas totales o promedio para cada día
ventas_por_dia = df_ventas.groupby('Fecha de Compra')['Cantidad Pedida'].sum().reset_index()
ventas_por_dia['Fecha de Compra'] = pd.to_datetime(ventas_por_dia['Fecha de Compra'])
ventas_por_dia.set_index('Fecha de Compra', inplace=True)

# Calcular el promedio de ventas por día
ventas_promedio_por_dia = ventas_por_dia.resample('D').mean()

# Mostrar el DataFrame con las de ventas promedio
ventas_promedio_por_dia
# Out:
#                  Cantidad Pedida
# Fecha de Compra
# 2019-09-01              1.416667
# 2019-09-02              1.472313
# 2019-09-03              1.396774
# 2019-09-04              1.378882
# 2019-09-05              1.385666
# 2019-09-06              1.365931
# 2019-09-07              1.347403
# 2019-09-08              1.357827
# 2019-09-09              1.394322
# 2019-09-10              1.388715
# 2019-09-11              1.398773
# 2019-09-12              1.406250
# 2019-09-13              1.317901
# 2019-09-14              1.399381
# 2019-09-15              1.430341
# 2019-09-16              1.387417
# 2019-09-17              1.371601
# 2019-09-18              1.401274
# 2019-09-19              1.418182
# 2019-09-20              1.335385
# 2019-09-21              1.378549
# 2019-09-22              1.338762
# 2019-09-23              1.375000
# 2019-09-24              1.308157
# 2019-09-25              1.361486
# 2019-09-26              1.331230
# 2019-09-27              1.417417
# ...

# %%
import pandas as pd
import plotly.express as px
import numpy as np

# Crear una columna para el día de la semana
df_ventas['Fecha de Compra'] = pd.to_datetime(df_ventas['Fecha de Compra'])
df_ventas['Día de la Semana'] = df_ventas['Fecha de Compra'].dt.day_name()

# Crear una columna para el mes
df_ventas['Mes'] = df_ventas['Fecha de Compra'].dt.strftime('%B')  # Usamos '%B' para obtener el nombre completo del mes

# Crear una tabla pivote con ventas por día de la semana y mes
ventas_pivot = df_ventas.pivot_table(index='Día de la Semana', columns='Mes', values='Cantidad Pedida', aggfunc=np.sum, fill_value=0)
dias_semana = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
meses_ordenados = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
ventas_pivot = ventas_pivot.reindex(index=dias_semana, columns=meses_ordenados)

# Configurar el tamaño del gráfico
fig = px.imshow(ventas_pivot,
                color_continuous_scale='YlGnBu',
                labels=dict(x="Mes", y="Día de la Semana", color="Ventas"))

# Configurar etiquetas de los ejes
fig.update_xaxes(tickangle=45, tickvals=list(range(len(ventas_pivot.columns))), ticktext=ventas_pivot.columns)
fig.update_yaxes(tickvals=list(range(len(ventas_pivot.index))), ticktext=ventas_pivot.index)

# Agregar anotaciones y formato
fig.update_traces(text=ventas_pivot.values, showscale=True)
fig.update_layout(title='Ventas por Día de la Semana a lo Largo de los Meses',
                  xaxis_title='Mes',
                  yaxis_title='Día de la Semana')
# Mostrar el gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px

# Supongamos que ya tienes datos_combinados como DataFrame
# ...

# Calcular la columna 'Mes' a partir de la columna 'Fecha de Pedido'
df_ventas['Fecha de Pedido'] = pd.to_datetime(df_ventas['Fecha de Pedido'], format='%Y-%m-%d %H:%M:%S')
df_ventas['Mes'] = df_ventas['Fecha de Pedido'].dt.month

# Definir el orden deseado de los días de la semana
orden_dias_semana = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Convertir 'Día de la Semana' a categoría y establecer el orden deseado
df_ventas['Día de la Semana'] = pd.Categorical(df_ventas['Día de la Semana'], categories=orden_dias_semana, ordered=True)

# Agrupar los datos por mes y día de la semana y calcular la suma de las ventas
ventas_por_mes_y_dia = df_ventas.groupby(['Mes', 'Día de la Semana'])['Cantidad Pedida'].sum().reset_index()

# Ordenar los valores de 'Cantidad Pedida' de menor a mayor dentro de cada columna
ventas_por_mes_y_dia = ventas_por_mes_y_dia.sort_values(['Mes', 'Día de la Semana', 'Cantidad Pedida'], ascending=[True, True, True])

# Crear el gráfico de barras agrupadas con Plotly Express
fig = px.bar(ventas_por_mes_y_dia, x='Mes', y='Cantidad Pedida', color='Día de la Semana',
             title='Variación de ventas por día de la semana según el mes',
             labels={'Mes': 'Mes', 'Cantidad Pedida': 'Cantidad de Ventas', 'Día de la Semana': 'Día de la Semana'})

# Mostrar el gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
from datetime import datetime

# Crear un gráfico de tendencia de ventas promedio por día con Plotly
fig = px.line(ventas_promedio_por_dia, x=ventas_promedio_por_dia.index, y='Cantidad Pedida', title='Ventas Promedio por Día')
fig.update_xaxes(title='Fecha de Compra')
fig.update_yaxes(title='Ventas Promedio')

# Definir las fechas que deseas resaltar y convertirlas a objetos datetime
fechas_resaltadas = ['2019-02-14', '2019-07-04', '2019-05-28', '2019-10-31', '2019-12-25', '2020-01-01']
fechas_resaltadas = [datetime.strptime(fecha, '%Y-%m-%d') for fecha in fechas_resaltadas]

# Agregar líneas verticales o marcas en las fechas resaltadas con la fecha correspondiente en la etiqueta
for fecha in fechas_resaltadas:
    fecha_timestamp = fecha.timestamp() * 1000  # Convertir a marca de tiempo en milisegundos
    fecha_formateada = fecha.strftime('%Y-%m-%d')  # Formatear la fecha como 'YYYY-MM-DD'
    fig.add_vline(x=fecha_timestamp, line_dash="dash", line_color="red")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px

# Convertir la columna 'Fecha de Pedido' a formato datetime
df_ventas['Fecha de Pedido'] = pd.to_datetime(df_ventas['Fecha de Pedido'], format='%m/%d/%y %H:%M', errors='coerce')


# Agregar una columna para el día de la semana
df_ventas['Día de la Semana'] = df_ventas['Fecha de Pedido'].dt.day_name()

# Agrupar los datos por día de la semana y calcular la suma de las ventas
ventas_por_dia_semana = df_ventas.groupby('Día de la Semana')['Cantidad Pedida'].sum().reset_index()

# Ordenar los días de la semana en el orden correcto
dias_semana = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
ventas_por_dia_semana['Día de la Semana'] = pd.Categorical(ventas_por_dia_semana['Día de la Semana'], categories=dias_semana, ordered=True)
ventas_por_dia_semana = ventas_por_dia_semana.sort_values('Día de la Semana')

# Crear el gráfico de barras con Plotly Express
fig = px.bar(ventas_por_dia_semana, x='Día de la Semana', y='Cantidad Pedida',
             title='Variación de Ventas por Día de la Semana',
             labels={'Día de la Semana': 'Día de la Semana', 'Cantidad Pedida': 'Cantidad de Ventas'})

# Mostrar el gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
